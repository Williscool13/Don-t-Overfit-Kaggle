# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv', engine='python')
df.drop('id', axis=1, inplace=True)

y_train = df['target']
X_train = df.drop(['target'], axis=1)

# %%
test_df = pd.read_csv('test.csv', engine='python')
temp_id = test_df['id']

X_test = test_df.drop('id', axis=1)

# %%
#basic l2 regression
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(C=100).fit(X_train, y_train)


y_pred_clf = clf.predict(X_test)
# Out:
# /home/william/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
#reduce features to 15, and l2 regression
from sklearn.feature_selection import RFE

temp = LogisticRegression(C=1.0, penalty='l2')
selector = RFE(temp, 15, step=1)
new_X_train = selector.fit_transform(X_train, y_train)
feature_removed_clf = LogisticRegression(C=1.0, penalty='l2').fit(new_X_train, y_train)


new_X_test = selector.transform(X_test)
y_pred_ridge = feature_removed_clf.predict(new_X_test)
# Out:
# /home/william/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/william/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/william/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/william/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
answer = pd.DataFrame({'id': temp_id, 'target': y_pred_ridge})
answer.head()
# Out:
#     id  target
# 0  250     1.0
# 1  251     1.0
# 2  252     1.0
# 3  253     1.0
# 4  254     1.0

# %%
answer.to_csv('answer.csv', index=False)
